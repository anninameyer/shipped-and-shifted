# %% [markdown]
# # Uploading raw data and metadata to ENA

# %% [markdown]
# ### first, install the required plugin:

# %% [markdown]
# first, activate the qiime2-amplicon-2024.10 env

# %%
#run in therminal:
! pip install git+https://github.com/bokulich-lab/q2-ena-uploader.git
# Out:
# ...
#   Cloning https://github.com/bokulich-lab/q2-ena-uploader.git to /scratch/meyeanni/tmp/pip-req-build-pt08e7a0
#   Running command git clone --filter=blob:none --quiet https://github.com/bokulich-lab/q2-ena-uploader.git /scratch/meyeanni/tmp/pip-req-build-pt08e7a0
#   Resolved https://github.com/bokulich-lab/q2-ena-uploader.git to commit 06c26dc2be12285459e5c98c0bee78d3d71a648b
#   Installing build dependencies ... /^C
# anceled

# %%
#also run in terminal:
qiime dev refresh-cache
qiime ena-uploader --help

# %%
import os
import qiime2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/meyeanni/Desktop/git_sourdough/shipped-and-shifted/preprocessing-amplicons

# %%
import os
import qiime2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the working directory
wd = '/home/meyeanni/cloud/meyeanni/LP4'

# Change to the working directory
os.chdir(wd)

# Verify current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /home/meyeanni/cloud/meyeanni/LP4

# %%
import qiime2 as q2

from qiime2 import (Artifact,
                    Metadata as qmd)

from qiime2.plugins import (cutadapt,
                            demux,
                            feature_table as qft,
                            taxa as q2t,)

from qiime2 import Metadata
from qiime2 import Visualization

from qiime2.plugins.feature_table.methods import (merge_seqs, merge, filter_seqs, filter_samples, filter_features) 
import qiime2.plugins.feature_classifier.actions as feature_classifier_actions
import qiime2.plugins.metadata.actions as metadata_actions
import qiime2.plugins.taxa.actions as taxa_actions
import qiime2.plugins.phylogeny.actions as phylogeny_actions
from qiime2.plugins.fragment_insertion.methods import sepp


# %matplotlib inline
# Out:
# fatal: bad revision 'HEAD'
# fatal: bad revision 'HEAD'

# %% [markdown]
# ## filter the 16S and ITS reads (which are currently separated), then recombined them in one single read file

# %%
#import metadata to change ids
meta1 = pd.read_csv(
    'LP4_metadata.tsv',
    sep='\t',
    index_col=0
)
meta1
# Out:
#                         label_barcode1 label_barcode2      created_date  \
# SampleID
# 366293_001-LP4-16S-0001   CAAGTCGTTTAC   AGCCTTCGTCGC  16.10.2024 14:59
# 366293_002-LP4-16S-0002   AAGTTCGCGCTA   TTCCTTAGTAGT  16.10.2024 14:59
# 366293_003-LP4-16S-0003   TATTCTAAGCGC   CGTTTGGAATGA  16.10.2024 14:59
# 366293_004-LP4-16S-0004   GCGGGCCTTTGC   TACGGATTATGG  16.10.2024 14:59
# 366293_005-LP4-16S-0005   GTGTCAGATGTC   ACATACTGAGCA  16.10.2024 14:59
# ...                                ...            ...               ...
# 366292_648-LP4-ITS-1148   GCCGATTCGGAA   TAGGAGAGACAG  16.10.2024 14:59
# 366292_649-LP4-ITS-1149   GACACATTTCTG   GGTGTGAGAAAG  16.10.2024 14:59
# 366292_650-LP4-ITS-1150   TACAGTCTCATG   GTTCCATCGGCC  16.10.2024 14:59
# 366292_651-LP4-ITS-1151   CTTGTCCACCTT   TACTTAAACATC  16.10.2024 14:59
# 366292_652-LP4-ITS-1152   AGTTAAGCTTCC   AGGGAGCTTCGG  16.10.2024 14:59
#
#                         amplicon     unique_id  sample_id plate  \
# SampleID
# ...

# %%
#import again:
meta2 = pd.read_csv(
    'id_remapping.tsv',
    sep='\t',
    index_col=1
)
meta2
# Out:
#                                              sample ID  \
# sample ID trunc
# 366293_001-LP4-16S-0001  366293_001-LP4-16S-0001_S1182
# 366293_002-LP4-16S-0002   366293_002-LP4-16S-0002_S590
# 366293_003-LP4-16S-0003   366293_003-LP4-16S-0003_S889
# 366293_004-LP4-16S-0004   366293_004-LP4-16S-0004_S543
# 366293_005-LP4-16S-0005  366293_005-LP4-16S-0005_S2302
# ...                                                ...
# 366292_648-LP4-ITS-1148  366292_648-LP4-ITS-1148_S1984
# 366292_649-LP4-ITS-1149   366292_649-LP4-ITS-1149_S633
# 366292_650-LP4-ITS-1150  366292_650-LP4-ITS-1150_S1169
# 366292_651-LP4-ITS-1151  366292_651-LP4-ITS-1151_S1711
# 366292_652-LP4-ITS-1152   366292_652-LP4-ITS-1152_S818
#
#                          forward sequence count  reverse sequence count
# sample ID trunc
# 366293_001-LP4-16S-0001                     405                     405
# 366293_002-LP4-16S-0002                      35                      35
# ...

# %%
merge = meta1.merge(meta2, how = 'left', left_on = meta1.index, right_on = meta2.index)
merge
# Out:
#                         key_0 label_barcode1 label_barcode2      created_date  \
# 0     366293_001-LP4-16S-0001   CAAGTCGTTTAC   AGCCTTCGTCGC  16.10.2024 14:59
# 1     366293_002-LP4-16S-0002   AAGTTCGCGCTA   TTCCTTAGTAGT  16.10.2024 14:59
# 2     366293_003-LP4-16S-0003   TATTCTAAGCGC   CGTTTGGAATGA  16.10.2024 14:59
# 3     366293_004-LP4-16S-0004   GCGGGCCTTTGC   TACGGATTATGG  16.10.2024 14:59
# 4     366293_005-LP4-16S-0005   GTGTCAGATGTC   ACATACTGAGCA  16.10.2024 14:59
# ...                       ...            ...            ...               ...
# 2299  366292_648-LP4-ITS-1148   GCCGATTCGGAA   TAGGAGAGACAG  16.10.2024 14:59
# 2300  366292_649-LP4-ITS-1149   GACACATTTCTG   GGTGTGAGAAAG  16.10.2024 14:59
# 2301  366292_650-LP4-ITS-1150   TACAGTCTCATG   GTTCCATCGGCC  16.10.2024 14:59
# 2302  366292_651-LP4-ITS-1151   CTTGTCCACCTT   TACTTAAACATC  16.10.2024 14:59
# 2303  366292_652-LP4-ITS-1152   AGTTAAGCTTCC   AGGGAGCTTCGG  16.10.2024 14:59
#
# ...

# %%
merge.index = merge['sample ID']
merge
# Out:
#                                                  key_0 label_barcode1  \
# sample ID
# 366293_001-LP4-16S-0001_S1182  366293_001-LP4-16S-0001   CAAGTCGTTTAC
# 366293_002-LP4-16S-0002_S590   366293_002-LP4-16S-0002   AAGTTCGCGCTA
# 366293_003-LP4-16S-0003_S889   366293_003-LP4-16S-0003   TATTCTAAGCGC
# 366293_004-LP4-16S-0004_S543   366293_004-LP4-16S-0004   GCGGGCCTTTGC
# 366293_005-LP4-16S-0005_S2302  366293_005-LP4-16S-0005   GTGTCAGATGTC
# ...                                                ...            ...
# 366292_648-LP4-ITS-1148_S1984  366292_648-LP4-ITS-1148   GCCGATTCGGAA
# 366292_649-LP4-ITS-1149_S633   366292_649-LP4-ITS-1149   GACACATTTCTG
# 366292_650-LP4-ITS-1150_S1169  366292_650-LP4-ITS-1150   TACAGTCTCATG
# 366292_651-LP4-ITS-1151_S1711  366292_651-LP4-ITS-1151   CTTGTCCACCTT
# 366292_652-LP4-ITS-1152_S818   366292_652-LP4-ITS-1152   AGTTAAGCTTCC
#
#                               label_barcode2      created_date amplicon  \
# sample ID
# ...

# %%
merge.to_csv('LP4_metadata_reind.tsv', sep='\t', index=True)

# %%
# summarize the import files
qiime demux summarize --i-data ITS/ITS-demux-paired-end.qza --o-visualization ITS/ITS-demux-paired-end.qzv

qiime demux summarize --i-data 16S/16S-demux-paired-end.qza --o-visualization 16S/16S-demux-paired-end.qzv

# %% [markdown]
# ## now filter for only shipping samples in both 16S and ITS data before merging them.

# %%
! qiime demux filter-samples \
  --i-demux artifacts/16S/16S-demux-paired-end.qza \
  --m-metadata-file LP4_metadata_reind_no_fails_16S.tsv \
  --p-where "[project]='shipping'" \
  --o-filtered-demux artifacts/16S/16S-demux-shipping-only.qza
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: artifacts/16S/16S-demux-shipping-only.qza

# %%
#to checkout if the sample count makes sense: 
# !qiime demux summarize --i-data artifacts/16S/16S-demux-shipping-only.qza --o-visualization artifacts/16S/16S-demux-shipping-only.qzv
# Out:
# Saved Visualization to: artifacts/16S/16S-demux-shipping-only.qzv

# %% [markdown]
# and for ITS:

# %%
! qiime demux filter-samples \
  --i-demux artifacts/ITS/ITS-demux-paired-end.qza \
  --m-metadata-file LP4_metadata_reind_no_fails_ITS.tsv \
  --p-where "[project]='shipping'" \
  --o-filtered-demux artifacts/ITS/ITS-demux-shipping-only.qza
# Out:
# Saved SampleData[PairedEndSequencesWithQuality] to: artifacts/ITS/ITS-demux-shipping-only.qza

# %%
#to checkout if the sample count makes sense: 
# !qiime demux summarize --i-data artifacts/ITS/ITS-demux-shipping-only.qza --o-visualization artifacts/ITS/ITS-demux-shipping-only.qzv
# Out:
# Saved Visualization to: artifacts/ITS/ITS-demux-shipping-only.qzv

# %% [markdown]
# -> looks fine, now combined the 16S and ITS to the same artifact:

# %%
# !qiime tools export --input-path artifacts/16S/16S-demux-shipping-only.qza --output-path artifacts/16S/exported_demux_shipping
# !qiime tools export --input-path artifacts/ITS/ITS-demux-shipping-only.qza --output-path artifacts/ITS/exported_demux_shipping
# qiime tools export --input-path dada2-stats.qza --output-path exported_stats
# qiime tools export --input-path dada2-table.qza --output-path exported_table
# Out:
# Exported artifacts/16S/16S-demux-shipping-only.qza as SingleLanePerSamplePairedEndFastqDirFmt to directory artifacts/16S/exported_demux_shipping
# Exported artifacts/ITS/ITS-demux-shipping-only.qza as SingleLanePerSamplePairedEndFastqDirFmt to directory artifacts/ITS/exported_demux_shipping

# %% [markdown]
# then put it all in the same folder, reimport ant then finally I have it all in one single artifact for ENA upload

# %% [markdown]
# -> copy the 16S data in the ITS export folder (since 16S is smaller to copy and move around)

# %%
# !qiime tools import \
--type 'SampleData[PairedEndSequencesWithQuality]' \
--input-path ~/public/Cloud/meyeanni/LP4/artifacts/ITS/exported_demux_shipping \
--input-format CasavaOneEightSingleLanePerSampleDirFmt \
--output-path shipping_ena/shipping-demux-paired-end.qza
# Out:
# There was a problem importing /home/meyeanni/public/Cloud/meyeanni/LP4/artifacts/ITS/exported_demux_shipping:
#
#   /home/meyeanni/public/Cloud/meyeanni/LP4/artifacts/ITS/exported_demux_shipping is not a(n) CasavaOneEightSingleLanePerSampleDirFmt:
#
#   These samples do not have matching pairs of forward and reverse reads: {'366294_242-LP4-16S-0742_S760', '366294_209-LP4-16S-0709_S25', '366294_121-LP4-16S-0621_S1838'}

# %% [markdown]
# ## -> ok not working.. will have to upload the data separately once for 16S and once for ITS resulting in two separate bioprojects. use these files:

# %%
--o-filtered-demux artifacts/ITS/ITS-demux-shipping-only.qza
--o-filtered-demux artifacts/16S/16S-demux-shipping-only.qza

# %% [markdown]
# continue with preparing the metadata files

# %% [markdown]
# # prepare metadata qzas and check if IDs are matching

# %%
import os
import qiime2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the working directory
wd = '/Users/meyeanni/Desktop/Manuscripts/shipping/ENA-upload/16S'

# Change to the working directory
os.chdir(wd)

# Verify current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/meyeanni/Desktop/Manuscripts/shipping/ENA-upload/16S

# %% [markdown]
# set those in terminal:

# %%
`export ENA_USERNAME=xxx`

`export ENA_PASSWORD=xxx`

# %%
pwd
# Out:
# '/home/meyeanni/cloud/meyeanni/LP4'

# %%
import pandas as pd
import numpy as np
from lxml import etree
import re
from datetime import datetime
import qiime2
from q2_types.per_sample_sequences import SingleLanePerSamplePairedEndFastqDirFmt, CasavaOneEightSingleLanePerSampleDirFmt

# %% [markdown]
# run it all interminal:

# %%
qiime tools import \
  --type ENAMetadataStudy \
  --input-path study_metadata.tsv \
  --output-path study_metadata.qza

# %%
qiime tools import \
  --type ENAMetadataSamples \
  --input-path sample_metadata.tsv \
  --output-path sample_metadata.qza

# %%
qiime tools import \
  --type ENAMetadataExperiment \
  --input-path experiment_metadata.tsv \
  --output-path experiment_metadata.qza

# %% [markdown]
# # now check that all identifiers match

# %%
# Load your demux.qza file
demux = qiime2.Artifact.load('16S-demux-shipping-only.qza')
# View as the directory format
demux_dir = demux.view(SingleLanePerSamplePairedEndFastqDirFmt)

# %%
demux_df = demux_dir.manifest.view(pd.DataFrame)
demux_df.head()
# Out:
#                                                                          forward  \
# sample-id
# 366294_118-LP4-16S-0618_S530   /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366294_121-LP4-16S-0621_S1838  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366294_124-LP4-16S-0624_S728   /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366294_128-LP4-16S-0628_S1350  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366294_130-LP4-16S-0630_S1942  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
#
#                                                                          reverse
# sample-id
# 366294_118-LP4-16S-0618_S530   /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366294_121-LP4-16S-0621_S1838  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366294_124-LP4-16S-0624_S728   /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366294_128-LP4-16S-0628_S1350  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# ...

# %%
fastq_ids_set = set(demux_df.index)

# %%
md = pd.read_csv('sample_metadata.tsv', sep='\t')

# %%
md
# Out:
#                              alias  taxon_id  collection date  \
# 0    366294_216-LP4-16S-0716_S1282    870726             2024
# 1     366294_191-LP4-16S-0691_S103    870726             2024
# 2    366294_228-LP4-16S-0728_S1437    870726             2024
# 3     366294_254-LP4-16S-0754_S990    870726             2024
# 4     366294_268-LP4-16S-0768_S515    870726             2024
# ..                             ...       ...              ...
# 100   366294_263-LP4-16S-0763_S380    870726             2024
# 101  366294_264-LP4-16S-0764_S2275    870726             2024
# 102   366294_265-LP4-16S-0765_S365    870726             2024
# 103   366294_266-LP4-16S-0766_S677    870726             2024
# 104    366294_267-LP4-16S-0767_S95    870726             2024
#
#     geographic location (country and/or sea)  geographic location (latitude)  \
# 0                                Switzerland                       47.377764
# ...

# %%
are_ids_identical = (fastq_ids_set == set(md['alias']))
print(f"\nAre the sets of IDs identical? {are_ids_identical}")
# Out:
# Are the sets of IDs identical? True

# %% [markdown]
# ->perfect, good to go?

# %%
# %%bash
#
# qiime ena-uploader submit-all \
#   --i-study study_metadata.qza \
#   --i-samples sample_metadata.qza \
#   --i-experiment experiment_metadata.qza \
#   --i-demux 16S-demux-shipping-only.qza \
#   --p-submission-hold-date 2025-07-29 \
#   --p-dev False\
#   --p-action ADD \
#   --o-sample-submission-receipt samples_receipt.qza \
#   --o-read-submission-receipt reads_receipt.qza \
#   --o-file-upload-metadata upload_metadata.qza

# %% [markdown]
# since the platform was wrong, it failed.. however I do have some of the receipts that are correct, just have to reupload the experiment_metadata and samples, therefore try this:

# %%
qiime ena-uploader transfer-files-to-ena \
  --i-demux 16S-demux-shipping-only.qza \
  --p-action ADD \
  --o-metadata transfer_metadata.qza

# %%
qiime ena-uploader submit-metadata-reads \
  --i-demux 16S-demux-shipping-only.qza \
  --i-experiment experiment_metadata.qza \
  --i-samples-submission-receipt samples_receipt.qza \
  --i-file-transfer-metadata transfer_metadata.qza \
  --p-submission-hold-date 2025-07-28 \
  --p-action ADD \
  --p-dev \
  --o-submission-receipt receipt.qza

# %% [markdown]
# -->> seems it worked now, now check the server

# %%
qiime tools export \
  --input-path samples_receipt.qza \
  --output-path exported_samples_receipt

qiime tools export \
  --input-path reads_receipt.qza \
  --output-path exported_reads_receipt

qiime tools export \
  --input-path upload_metadata.qza \
  --output-path exported_upload_metadata


qiime tools export \
  --input-path receipt.qza \
  --output-path exported_receipt

# %% [markdown]
# # then do the same for fungi:

# %%
import os
import qiime2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Define the working directory
wd = '/Users/meyeanni/Desktop/Manuscripts/shipping/ENA-upload/ITS'

# Change to the working directory
os.chdir(wd)

# Verify current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/meyeanni/Desktop/Manuscripts/shipping/ENA-upload/ITS

# %% [markdown]
# (change to the ITS folder in terminal first, then run again the same with the updated metadata files-> identifiers and primers updated)

# %%
qiime tools import \
  --type ENAMetadataStudy \
  --input-path study_metadata.tsv \
  --output-path study_metadata.qza

# %%
qiime tools import \
  --type ENAMetadataSamples \
  --input-path sample_metadata.tsv \
  --output-path sample_metadata.qza

# %%
qiime tools import \
  --type ENAMetadataExperiment \
  --input-path experiment_metadata.tsv \
  --output-path experiment_metadata.qza

# %% [markdown]
# check if identifiers match also here:

# %%
# Load your demux.qza file
demux = qiime2.Artifact.load('ITS-demux-shipping-only.qza')
# View as the directory format
demux_dir = demux.view(SingleLanePerSamplePairedEndFastqDirFmt)

# %%
demux_df = demux_dir.manifest.view(pd.DataFrame)
demux_df.head()
# Out:
#                                                                          forward  \
# sample-id
# 366292_118-LP4-ITS-0618_S2148  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366292_121-LP4-ITS-0621_S739   /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366292_124-LP4-ITS-0624_S1257  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366292_128-LP4-ITS-0628_S1205  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366292_130-LP4-ITS-0630_S2300  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
#
#                                                                          reverse
# sample-id
# 366292_118-LP4-ITS-0618_S2148  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366292_121-LP4-ITS-0621_S739   /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366292_124-LP4-ITS-0624_S1257  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# 366292_128-LP4-ITS-0628_S1205  /var/folders/mn/3_jl7ykj1qd6kmb2tjjqbgt80000gp...
# ...

# %%
fastq_ids_set = set(demux_df.index)

# %%
md = pd.read_csv('sample_metadata.tsv', sep='\t')

# %%
are_ids_identical = (fastq_ids_set == set(md['alias']))
print(f"\nAre the sets of IDs identical? {are_ids_identical}")
# Out:
# Are the sets of IDs identical? True

# %% [markdown]
# ->perfect, ready to go.  this time, the upload in one go should work since the platform should be correct from the beginning onwards..

# %%
# %%bash
#
# qiime ena-uploader submit-all \
#   --i-study study_metadata.qza \
#   --i-samples sample_metadata.qza \
#   --i-experiment experiment_metadata.qza \
#   --i-demux ITS-demux-shipping-only.qza \
#   --p-submission-hold-date 2025-07-29 \
#   --p-dev False\
#   --p-action ADD \
#   --o-sample-submission-receipt samples_receipt.qza \
#   --o-read-submission-receipt reads_receipt.qza \
#   --o-file-upload-metadata upload_metadata.qza

# %% [markdown]
# check if it worked: (in bash)

# %%
qiime tools export \
  --input-path samples_receipt.qza \
  --output-path exported_samples_receipt

qiime tools export \
  --input-path reads_receipt.qza \
  --output-path exported_reads_receipt

qiime tools export \
  --input-path upload_metadata.qza \
  --output-path exported_upload_metadata

# %% [markdown]
# -->> looks like it all worked seemlessly.. check portal after 24 or 48 hrs to see if it is all online
